# %%
from task2 import value_witness as vw
# Out:
# Генерация решета Аткина до N=10000000...
# Решето Аткина сгенерировано.

# %%
vw.main(*vw.init_n_list_and_filename_pdf())
# Out:
# Выберете вариант промежутка для графика чисел N
#  1: N = [1e+2, 1e+4];
#  2: N = [1e+4, 1e+6];
#  3: N = [1e+6, 1e+7].
# Вариант: 1
# Время расчета (c):  	5.537

# %%
vw.main(*vw.init_n_list_and_filename_pdf())
# Out:
# Выберете вариант промежутка для графика чисел N
#  1: N = [1e+2, 1e+4];
#  2: N = [1e+4, 1e+6];
#  3: N = [1e+6, 1e+7].
# Вариант: 2
# Время расчета (c):  	45.733

# %%
vw.main(*vw.init_n_list_and_filename_pdf())
# Out:
# Выберете вариант промежутка для графика чисел N
#  1: N = [1e+2, 1e+4];
#  2: N = [1e+4, 1e+6];
#  3: N = [1e+6, 1e+7].
# Вариант: 3
# Время расчета (c):  	372.234
