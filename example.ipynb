# %%
from mean_value_witness import *

# %%
main(*init_n_list_and_filename_pdf())
# Out:
# Выберете вариант промежутка для графика чисел N
#  1: N = [1e+2, 1e+4];
#  2: N = [1e+4, 1e+6];
#  3: N = [1e+6, 1e+7].
# Вариант: 1
# Генерация простых чисел до N=10000000...
# Простые числа сгенерированы за 0.316 (с.)
# Время расчета для n=pq (c.):  	5.028
# Время расчета для n=pqr (c.):  	7.045

# %%
main(*init_n_list_and_filename_pdf())
# Out:
# Выберете вариант промежутка для графика чисел N
#  1: N = [1e+2, 1e+4];
#  2: N = [1e+4, 1e+6];
#  3: N = [1e+6, 1e+7].
# Вариант: 2
# Время расчета для n=pq (c.):  	39.470
# Время расчета для n=pqr (c.):  	86.040

# %%
main(*init_n_list_and_filename_pdf())
# Out:
# Выберете вариант промежутка для графика чисел N
#  1: N = [1e+2, 1e+4];
#  2: N = [1e+4, 1e+6];
#  3: N = [1e+6, 1e+7].
# Вариант: 3
# Время расчета для n=pq (c.):  	361.697
# Время расчета для n=pqr (c.):  	810.434
