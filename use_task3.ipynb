# %%
from task3.value_witness_pqr import *
# Out:
# Генерация простых чисел до N=10000000...
# Простые числа сгенерированы за 0.332 (с.)

# %%
main_pqr(*init_n_list_and_filename_pdf())
# Out:
# Выберете вариант промежутка для графика чисел N
#  1: N = [1e+2, 1e+4];
#  2: N = [1e+4, 1e+6];
#  3: N = [1e+6, 1e+7].
# Вариант: 1
# Время расчета для n=pq (c.):  	5.300
# Время расчета для n=pqr (c.):  	7.854

# %%
main_pqr(*init_n_list_and_filename_pdf())
# Out:
# Выберете вариант промежутка для графика чисел N
#  1: N = [1e+2, 1e+4];
#  2: N = [1e+4, 1e+6];
#  3: N = [1e+6, 1e+7].
# Вариант: 2
# Время расчета для n=pq (c.):  	42.258
# Время расчета для n=pqr (c.):  	92.215
